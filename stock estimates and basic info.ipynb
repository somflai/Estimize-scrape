# %%
# Imports
import requests
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import os
import re
import time
import csv
import json
import random
import requests
import pandas as pd
import numpy as np

from datetime import date, timedelta, datetime

import selenium
from selenium import webdriver

# %%
webpage = requests.get("https://www.estimize.com")

# %%
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
script = webpage.text

# %% [markdown]
# ### printed file pointless ###

# %%
###/*def sign_in():
  #  url = 'https://www.estimize.com/users/sign_in'
   # browser.get(url)
    email_field = browser.find_element_by_name('username')
    password_field = browser.find_element_by_name('password')
    submit_btn = browser.find_element_by_xpath('//button[@type="submit"]')

    with open('credentials.json') as f:
        d = json.loads(f.read())
        username = d['glassdoor'][0]['username']
        password = d['glassdoor'][0]['password']

    email_field.send_keys(username)
    password_field.send_keys(password)
    submit_btn.click()

   ## time.sleep(1)
# Out:
#   File "C:\Users\somes\AppData\Local\Temp/ipykernel_4428/2342042520.py", line 4
#     email_field = browser.find_element_by_name('username')
#     ^
# IndentationError: unexpected indent

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.headless = False
browser = webdriver.Chrome(executable_path = 'C:/Users/somes/OneDrive/Documents/chromedrive/chromedriver.exe')

# %% [markdown]
# ### login page ###

# %%
conda install selenium
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Note: you may need to restart the kernel to use updated packages.
#
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %%
from selenium.webdriver.support.ui import WebDriverWait

# %%
#url = 'https://www.estimize.com/users/sign_in'
browser.get("https://www.estimize.com/users/sign_in")
browser.find_element_by_id("user_login").send_keys('Analyst_8910981')
browser.find_element_by_id("user_password").send_keys('nZQ9uiQdBPm6UQN')

browser.find_element_by_class_name("button-special.guest-submit").click()


## TEst if logged in

WebDriverWait(driver=browser, timeout=10).until(
    lambda x: x.execute_script("return document.readyState === 'complete'")
)
error_message = "Incorrect username or password."
# get the errors (if there are)
errors = browser.find_elements_by_class_name("flash_alert")
# print the errors optionally
# for e in errors:
#     print(e.text)
# if we find that error message within errors, then login is failed
if any(error_message in e.text for e in errors):
    print("[!] Login failed")
else:
    print("[+] Login successful")
# Out:
# [+] Login successful

# %% [markdown]
# ### fetch url links for scraping sites ###

# %%
link_sectors = browser.find_element_by_id("nav-item-browse").get_attribute('href')

# %%
browser.get(link_sectors)

# %%
resp = requests.get(link_sectors)

# %%
##we are at the sectors page time to go through the page

# %%
from lxml import html
import requests



tree = html.fromstring(resp.content)

# %%
elements = tree.xpath('//*[@class="category-list"]/li[*]/ul/li[*]/a')

# %%
base_url = "https://www.estimize.com/"

# %%
links = [base_url + element.attrib['href'] for element in elements]

# %%
links
# Out:
# ['https://www.estimize.com//sectors/consumer-discretionary/industries/auto-components',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/automobiles',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/distributors',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/diversified-consumer-services',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/hotels-restaurants-and-leisure',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/household-durables',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/internet-and-catalog-retail',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/leisure-equipment-and-products',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/media',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/multiline-retail',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/specialty-retail',
#  'https://www.estimize.com//sectors/consumer-discretionary/industries/textiles-apparel-and-luxury-goods',
#  'https://www.estimize.com//sectors/consumer-staples/industries/beverages',
#  'https://www.estimize.com//sectors/consumer-staples/industries/food-products',
#  'https://www.estimize.com//sectors/consumer-staples/industries/food-and-staples-retailing',
#  'https://www.estimize.com//sectors/consumer-staples/industries/household-and-personal-products',
#  'https://www.estimize.com//sectors/consumer-staples/industries/personal-products',
#  'https://www.estimize.com//sectors/consumer-staples/industries/tobacco',
#  'https://www.estimize.com//sectors/energy/industries/energy-equipment-and-services',
#  'https://www.estimize.com//sectors/energy/industries/oil-gas-and-consumable-fuels',
#  'https://www.estimize.com//sectors/financials/industries/capital-markets',
#  'https://www.estimize.com//sectors/financials/industries/commercial-banks',
#  'https://www.estimize.com//sectors/financials/industries/consumer-finance',
#  'https://www.estimize.com//sectors/financials/industries/diversified-financial-services',
#  'https://www.estimize.com//sectors/financials/industries/insurance',
#  'https://www.estimize.com//sectors/financials/industries/real-estate-development',
#  'https://www.estimize.com//sectors/financials/industries/thrifts-and-mortgage-finance',
#  'https://www.estimize.com//sectors/health-care/industries/biotechnology',
#  'https://www.estimize.com//sectors/health-care/industries/health-care-equipment-and-supplies',
#  'https://www.estimize.com//sectors/health-care/industries/health-care-providers-and-services',
#  'https://www.estimize.com//sectors/health-care/industries/health-care-technology',
#  'https://www.estimize.com//sectors/health-care/industries/life-sciences-tools-and-services',
#  'https://www.estimize.com//sectors/health-care/industries/pharmaceuticals',
#  'https://www.estimize.com//sectors/industrials/industries/aerospace-and-defense',
#  'https://www.estimize.com//sectors/industrials/industries/air-freight-and-logistics',
#  'https://www.estimize.com//sectors/industrials/industries/airlines',
#  'https://www.estimize.com//sectors/industrials/industries/building-products-1',
#  'https://www.estimize.com//sectors/industrials/industries/commercial-services-and-supplies',
#  'https://www.estimize.com//sectors/industrials/industries/construction-and-engineering',
#  'https://www.estimize.com//sectors/industrials/industries/electrical-equipment',
#  'https://www.estimize.com//sectors/industrials/industries/industrial-conglomerates',
#  'https://www.estimize.com//sectors/industrials/industries/machinery',
#  'https://www.estimize.com//sectors/industrials/industries/marine',
#  'https://www.estimize.com//sectors/industrials/industries/professional-services',
#  'https://www.estimize.com//sectors/industrials/industries/road-and-rail',
#  'https://www.estimize.com//sectors/industrials/industries/trading-companies-and-distribution',
#  'https://www.estimize.com//sectors/industrials/industries/transportation-infrastructure',
#  'https://www.estimize.com//sectors/information-technology/industries/communications-equipment',
#  'https://www.estimize.com//sectors/information-technology/industries/computers-and-peripherals',
#  'https://www.estimize.com//sectors/information-technology/industries/electronic-equip-dot-instruments',
#  'https://www.estimize.com//sectors/information-technology/industries/internet-software-and-services',
#  'https://www.estimize.com//sectors/information-technology/industries/it-services',
#  'https://www.estimize.com//sectors/information-technology/industries/office-electronics',
#  'https://www.estimize.com//sectors/information-technology/industries/semiconductors',
#  'https://www.estimize.com//sectors/information-technology/industries/software',
#  'https://www.estimize.com//sectors/materials/industries/chemicals',
#  'https://www.estimize.com//sectors/materials/industries/construction-materials',
#  'https://www.estimize.com//sectors/materials/industries/containers-and-packaging',
#  'https://www.estimize.com//sectors/materials/industries/metals-and-mining',
#  'https://www.estimize.com//sectors/materials/industries/paper-and-forest-products',
#  'https://www.estimize.com//sectors/telecommunication-services/industries/diversified-telecommunications',
#  'https://www.estimize.com//sectors/telecommunication-services/industries/wireless-telecommunication-services',
#  'https://www.estimize.com//sectors/utilities/industries/electric-utilities',
#  'https://www.estimize.com//sectors/utilities/industries/gas-utilities',
#  'https://www.estimize.com//sectors/utilities/industries/independent-power-producers',
#  'https://www.estimize.com//sectors/utilities/industries/multi-utilities',
#  'https://www.estimize.com//sectors/utilities/industries/water-utilities']

# %%
for link in links:
    browser.get(link)

# %%
browser.get('https://www.estimize.com/axl/fq3-2021?metric_name=eps&chart=table')

# %%
table = browser.find_element_by_class_name('rel-chart-tbl')

# %%
table = browser.find_element_by_class_name('rel-chart-tbl-estimize')

# %%
table.text

# %%
import requests
import lxml.html as lh
import pandas as pd

# %%
#making an xpath



resp = requests.get()


elements = tree.xpath('//*[@id="mw-content-text"]/div/table[2]/tbody/tr[*]/th/i/a')

# %%
tkrs = pd.read_csv('tickers.csv', index_col=None, header=None)[0].to_list()
tkrs
# Out:
# ['GPC',
#  'ALV',
#  'GNTX',
#  'COG',
#  'TOWR',
#  'DAN',
#  'SMP',
#  'ALSN',
#  'DORM',
#  'SRI',
#  'BWA',
#  'LKQ',
#  'APTV',
#  'CTB',
#  'THRM',
#  'VC',
#  'GT',
#  'LEA',
#  'AXL',
#  'TEN',
#  'SUP',
#  'SHYF',
#  'CORE',
#  'HZN',
#  'MOD',
#  'IEP',
#  'MGA',
#  'MPAA',
#  'FOXF',
#  'WGO',
#  'TSLA',
#  'HOG',
#  'F',
#  'FCAU',
#  'RACE',
#  'GM',
#  'HMC',
#  'NIO',
#  'THO',
#  'WGO',
#  'POOL',
#  'EDU',
#  'TAL',
#  'LRN',
#  'CSV',
#  'ZVO',
#  'SCI',
#  'WW',
#  'BID',
#  'RGS',
#  'ASCMA',
#  'FTDR',
#  'TMX',
#  'STRA',
#  'HMHC',
#  'LOPE',
#  'ATGE',
#  'BFAM',
#  'PRDO',
#  'APEI',
#  'HI',
#  'STON',
#  'MATW',
#  'HRB',
#  'DPZ',
#  'ISCA',
#  'CCL',
#  'SONC',
#  'QSR',
#  'TACO',
#  'CMG',
#  'LVS',
#  'BJRI',
#  'BLMN',
#  'BYD',
#  'DENN',
#  'EAT',
#  'WYND',
#  'SIX',
#  'DIN',
#  'TXRH',
#  'CHDN',
#  'NDLS',
#  'YUMC',
#  'HABT',
#  'YUM',
#  'RCL',
#  'DNKN',
#  'PENN',
#  'SBUX',
#  'MGM',
#  'SHAK',
#  'CAKE',
#  'LOCO',
#  'MCRI',
#  'RUTH',
#  'WING',
#  'DFRG',
#  'MCS',
#  'AAPL']

# %%
len(tkrs)
# Out:
# 100

# %%
browser.get('https://www.estimize.com/'+str(value)+'/fq1-2020?metric_name=eps&chart=table')

# %%
dbq1 = {}
dbq2 = {}

# %%
from lxml import html
import requests
from multiprocessing import Process


for i in range(len(tckrs)):
    lnk ='https://www.estimize.com/'+str(tkrs[i])+'/fq1-2020?metric_name=eps&chart=table'
    browser.get(lnk)
    try:
        WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, '//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[12]')))
    except:
        print('not found')
    elements = {}
    elements['tickers'] = tkrs[i]
    elements['Name'] = browser.find_element_by_xpath('//*[@class = "release-header-information-description"]/a').text
    elements['Sector'] = browser.find_element_by_xpath('//*[@class = "release-header-information-breadcrumb"]/span/a[1]/span').text
    elements['Industry'] = browser.find_element_by_xpath('//*[@class = "release-header-information-breadcrumb"]/span[2]/a[1]/span').text
    elements['followers'] = browser.find_element_by_xpath('//*[@class = "estimize-row summary-sub-title"][1]').text
    elements['Analysts'] = browser.find_element_by_xpath('//*[@class = "estimize-column separator-right"][2]/a').text
    elements['estimize q321'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[12]').text
    elements['estimize q221'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[11]').text
    elements['estimize q420'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[10]').text
    elements['estimize q320'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[9]').text
    elements['estimize q220'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[8]').text
    elements['estimize q120'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[1]/td[7]').text
    #mean
    elements['estimize mean q321'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[12]').text
    elements['estimize mean q221'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[11]').text
    elements['estimize mean q420'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[10]').text
    elements['estimize mean q320'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[9]').text
    elements['estimize mean q220'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[8]').text
    elements['estimize mean q120'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-estimize"]/tr[2]/td[7]').text
    #wall street
    elements['wall st q321'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[12]').text
    elements['wall st q221'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[11]').text
    elements['wall st q420'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[10]').text
    elements['wall st q320'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[9]').text
    elements['wall st q220'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[8]').text
    elements['wall st q120'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-wall-street"]/tr[1]/td[7]').text
    #actuals
    elements['actual q321'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[12]').text
    elements['actual q221'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[11]').text
    elements['actual q420'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[10]').text
    elements['actual q320'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[9]').text
    elements['actual q220'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[8]').text
    elements['actual q120'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[7]').text
    
    dbq2[i] = elements
# Out:
# not found
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15020/647470004.py in <module>
#      46     elements['actual q120'] = browser.find_element_by_xpath('//*[@class = "rel-chart-tbl-group rel-chart-tbl-group-actual"]/tr[1]/td[7]').text
#      47
# ---> 48     dbq2[i] = elements
#      49
#      50
#
# NameError: name 'dbq2' is not defined

# %%
dbq2
# Out:
# {0: {'tickers': 'TSLA',
#   'Name': 'Tesla Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '8,815',
#   'Analysts': '7,267',
#   'estimize q321': '1.80',
#   'estimize q221': '0.99',
#   'estimize q420': '0.85',
#   'estimize q320': '1.10',
#   'estimize q220': '0.65',
#   'estimize q120': '0.03',
#   'estimize mean q321': '1.67',
#   'estimize mean q221': '0.99',
#   'estimize mean q420': '0.80',
#   'estimize mean q320': '0.97',
#   'estimize mean q220': '0.58',
#   'estimize mean q120': '0.02',
#   'wall st q321': '1.62',
#   'wall st q221': '0.94',
#   'wall st q420': '0.75',
#   'wall st q320': '1.03',
#   'wall st q220': '0.56',
#   'wall st q120': '0',
#   'actual q321': '1.86',
#   'actual q221': '1.45',
#   'actual q420': '0.93',
#   'actual q320': '0.80',
#   'actual q220': '0.76',
#   'actual q120': '0.44'},
#  1: {'tickers': 'HOG',
#   'Name': 'Harley-Davidson, Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '285',
#   'Analysts': '430',
#   'estimize q321': '0.83',
#   'estimize q221': '1.21',
#   'estimize q420': '0.83',
#   'estimize q320': '0.31',
#   'estimize q220': '0.26',
#   'estimize q120': '0.11',
#   'estimize mean q321': '0.81',
#   'estimize mean q221': '1.21',
#   'estimize mean q420': '0.80',
#   'estimize mean q320': '0.28',
#   'estimize mean q220': '0.30',
#   'estimize mean q120': '0.17',
#   'wall st q321': '0.77',
#   'wall st q221': '1.21',
#   'wall st q420': '0.90',
#   'wall st q320': '0.21',
#   'wall st q220': '0.28',
#   'wall st q120': '0.11',
#   'actual q321': '1.18',
#   'actual q221': '1.41',
#   'actual q420': '1.68',
#   'actual q320': '-0.44',
#   'actual q220': '1.05',
#   'actual q120': '-0.35'},
#  2: {'tickers': 'F',
#   'Name': 'Ford Motor Co.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '2,314',
#   'Analysts': '1,775',
#   'estimize q321': '0.31',
#   'estimize q221': '0.15',
#   'estimize q420': '0.26',
#   'estimize q320': '0.01',
#   'estimize q220': '0.19',
#   'estimize q120': '-1.10',
#   'estimize mean q321': '0.30',
#   'estimize mean q221': '0.15',
#   'estimize mean q420': '0.24',
#   'estimize mean q320': '0.05',
#   'estimize mean q220': '0.17',
#   'estimize mean q120': '-0.85',
#   'wall st q321': '0.27',
#   'wall st q221': '-0.03',
#   'wall st q420': '0.22',
#   'wall st q320': '-0.07',
#   'wall st q220': '0.20',
#   'wall st q120': '-1.17',
#   'actual q321': '0.51',
#   'actual q221': '0.13',
#   'actual q420': '0.89',
#   'actual q320': '0.34',
#   'actual q220': '0.65',
#   'actual q120': '-0.35'},
#  3: {'tickers': 'FCAU',
#   'Name': 'Stellantis N.V.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '107',
#   'Analysts': '109',
#   'estimize q321': '1.66',
#   'estimize q221': '1.20',
#   'estimize q420': '0.86',
#   'estimize q320': '0.92',
#   'estimize q220': '0.58',
#   'estimize q120': '-1.05',
#   'estimize mean q321': '1.46',
#   'estimize mean q221': '1.01',
#   'estimize mean q420': '0.84',
#   'estimize mean q320': '0.93',
#   'estimize mean q220': '0.56',
#   'estimize mean q120': '-0.71',
#   'wall st q321': '1.12',
#   'wall st q221': '0.65',
#   'wall st q420': '0.52',
#   'wall st q320': '0.91',
#   'wall st q220': '0.49',
#   'wall st q120': '-1.48',
#   'actual q321': '1.19',
#   'actual q221': '14.44',
#   'actual q420': '0.52',
#   'actual q320': '1.41',
#   'actual q220': '0.89',
#   'actual q120': '-0.77'},
#  4: {'tickers': 'RACE',
#   'Name': 'Ferrari N.V.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '143',
#   'Analysts': '107',
#   'estimize q321': '1.32',
#   'estimize q221': '1.32',
#   'estimize q420': '1.36',
#   'estimize q320': '1.31',
#   'estimize q220': '0.97',
#   'estimize q120': '0.13',
#   'estimize mean q321': '1.36',
#   'estimize mean q221': '1.33',
#   'estimize mean q420': '1.36',
#   'estimize mean q320': '1.27',
#   'estimize mean q220': '0.97',
#   'estimize mean q120': '0.11',
#   'wall st q321': '1.18',
#   'wall st q221': '1.26',
#   'wall st q420': '1.32',
#   'wall st q320': '1.25',
#   'wall st q220': '1.00',
#   'wall st q120': '0.05',
#   'actual q321': '1.29',
#   'actual q221': '1.32',
#   'actual q420': '1.34',
#   'actual q320': '1.23',
#   'actual q220': '1.08',
#   'actual q120': '0.05'},
#  5: {'tickers': 'GM',
#   'Name': 'General Motors Company',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '982',
#   'Analysts': '727',
#   'estimize q321': '1.08',
#   'estimize q221': '2.04',
#   'estimize q420': '1.23',
#   'estimize q320': '1.80',
#   'estimize q220': '1.50',
#   'estimize q120': '-1.67',
#   'estimize mean q321': '1.19',
#   'estimize mean q221': '1.78',
#   'estimize mean q420': '1.21',
#   'estimize mean q320': '1.78',
#   'estimize mean q220': '1.49',
#   'estimize mean q120': '-0.85',
#   'wall st q321': '0.98',
#   'wall st q221': '1.82',
#   'wall st q420': '1.05',
#   'wall st q320': '1.60',
#   'wall st q220': '1.38',
#   'wall st q120': '-1.77',
#   'actual q321': '1.52',
#   'actual q221': '1.97',
#   'actual q420': '2.25',
#   'actual q320': '1.93',
#   'actual q220': '2.83',
#   'actual q120': '-0.50'},
#  6: {'tickers': 'HMC',
#   'Name': 'Honda Motor Co. Ltd ADR',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '17',
#   'Analysts': '9',
#   'estimize q321': '-',
#   'estimize q221': '-',
#   'estimize q420': '-',
#   'estimize q320': '-',
#   'estimize q220': '-',
#   'estimize q120': '-',
#   'estimize mean q321': '-',
#   'estimize mean q221': '-',
#   'estimize mean q420': '-',
#   'estimize mean q320': '-',
#   'estimize mean q220': '-',
#   'estimize mean q120': '-',
#   'wall st q321': '0.86',
#   'wall st q221': '0.60',
#   'wall st q420': '-0.44',
#   'wall st q320': '-',
#   'wall st q220': '-',
#   'wall st q120': '-',
#   'actual q321': '1.57',
#   'actual q221': '1.32',
#   'actual q420': '-0.44',
#   'actual q320': '-0.16',
#   'actual q220': '0.61',
#   'actual q120': '1.02'},
#  7: {'tickers': 'NIO',
#   'Name': 'Nio, Inc. ADS',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '485',
#   'Analysts': '319',
#   'estimize q321': '-0.05',
#   'estimize q221': '-0.04',
#   'estimize q420': '-0.12',
#   'estimize q320': '-0.05',
#   'estimize q220': '-0.13',
#   'estimize q120': '-0.26',
#   'estimize mean q321': '-0.03',
#   'estimize mean q221': '-0.04',
#   'estimize mean q420': '-0.11',
#   'estimize mean q320': '-0.06',
#   'estimize mean q220': '-0.13',
#   'estimize mean q120': '-0.26',
#   'wall st q321': '-0.06',
#   'wall st q221': '-0.07',
#   'wall st q420': '-0.15',
#   'wall st q320': '-0.08',
#   'wall st q220': '-0.17',
#   'wall st q120': '-0.31',
#   'actual q321': '-0.06',
#   'actual q221': '-0.08',
#   'actual q420': '-0.04',
#   'actual q320': '-0.14',
#   'actual q220': '-0.13',
#   'actual q120': '-0.15'},
#  8: {'tickers': 'THO',
#   'Name': 'Thor Industries Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '178',
#   'Analysts': '338',
#   'estimize q321': '2.74',
#   'estimize q221': '1.80',
#   'estimize q420': '1.70',
#   'estimize q320': '1.45',
#   'estimize q220': '-0.04',
#   'estimize q120': '0.75',
#   'estimize mean q321': '2.53',
#   'estimize mean q221': '1.69',
#   'estimize mean q420': '1.65',
#   'estimize mean q320': '1.45',
#   'estimize mean q220': '0.56',
#   'estimize mean q120': '0.79',
#   'wall st q321': '2.78',
#   'wall st q221': '1.56',
#   'wall st q420': '1.58',
#   'wall st q320': '1.39',
#   'wall st q220': '-0.25',
#   'wall st q120': '0.72',
#   'actual q321': '3.29',
#   'actual q221': '2.38',
#   'actual q420': '2.05',
#   'actual q320': '2.14',
#   'actual q220': '0.43',
#   'actual q120': '0.67'},
#  9: {'tickers': 'WGO',
#   'Name': 'Winnebago Industries Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Automobiles',
#   'followers': '106',
#   'Analysts': '186',
#   'estimize q321': '2.02',
#   'estimize q221': '1.62',
#   'estimize q420': '1.11',
#   'estimize q320': '0.98',
#   'estimize q220': '-0.35',
#   'estimize q120': '0.66',
#   'estimize mean q321': '1.91',
#   'estimize mean q221': '1.52',
#   'estimize mean q420': '1.08',
#   'estimize mean q320': '1.01',
#   'estimize mean q220': '-0.13',
#   'estimize mean q120': '0.72',
#   'wall st q321': '1.77',
#   'wall st q221': '1.42',
#   'wall st q420': '1.01',
#   'wall st q320': '0.94',
#   'wall st q220': '-0.45',
#   'wall st q120': '0.67',
#   'actual q321': '2.16',
#   'actual q221': '2.12',
#   'actual q420': '1.69',
#   'actual q320': '1.45',
#   'actual q220': '-0.26',
#   'actual q120': '0.67'},
#  10: {'tickers': 'POOL',
#   'Name': 'Pool Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Distributors',
#   'followers': '67',
#   'Analysts': '97',
#   'estimize q321': '4.03',
#   'estimize q221': '5.53',
#   'estimize q420': '1.30',
#   'estimize q320': '-',
#   'estimize q220': '2.29',
#   'estimize q120': '3.20',
#   'estimize mean q321': '4.02',
#   'estimize mean q221': '5.54',
#   'estimize mean q420': '1.34',
#   'estimize mean q320': '-',
#   'estimize mean q220': '2.29',
#   'estimize mean q120': '3.13',
#   'wall st q321': '3.83',
#   'wall st q221': '5.45',
#   'wall st q420': '1.14',
#   'wall st q320': '0.84',
#   'wall st q220': '2.19',
#   'wall st q120': '3.19',
#   'actual q321': '4.54',
#   'actual q221': '6.37',
#   'actual q420': '2.42',
#   'actual q320': '1.45',
#   'actual q220': '2.92',
#   'actual q120': '3.87'},
#  11: {'tickers': 'EDU',
#   'Name': 'New Oriental Education & Technology Group',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '119',
#   'Analysts': '125',
#   'estimize q321': '0.11',
#   'estimize q221': '0.04',
#   'estimize q420': '0.11',
#   'estimize q320': '0.04',
#   'estimize q220': '0.08',
#   'estimize q120': '0.03',
#   'estimize mean q321': '0.12',
#   'estimize mean q221': '0.04',
#   'estimize mean q420': '0.11',
#   'estimize mean q320': '0.04',
#   'estimize mean q220': '0.08',
#   'estimize mean q120': '0.03',
#   'wall st q321': '0.08',
#   'wall st q221': '0.03',
#   'wall st q420': '0.11',
#   'wall st q320': '0.03',
#   'wall st q220': '0.08',
#   'wall st q120': '-',
#   'actual q321': '0.10',
#   'actual q221': '0.04',
#   'actual q420': '0.12',
#   'actual q320': '0.03',
#   'actual q220': '0.09',
#   'actual q120': '0.04'},
#  12: {'tickers': 'TAL',
#   'Name': 'TAL Education Group',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '125',
#   'Analysts': '121',
#   'estimize q321': '0.07',
#   'estimize q221': '0.13',
#   'estimize q420': '0.09',
#   'estimize q320': '0.14',
#   'estimize q220': '0.09',
#   'estimize q120': '0.18',
#   'estimize mean q321': '0.10',
#   'estimize mean q221': '0.13',
#   'estimize mean q420': '0.09',
#   'estimize mean q320': '0.19',
#   'estimize mean q220': '0.12',
#   'estimize mean q120': '0.22',
#   'wall st q321': '0.02',
#   'wall st q221': '0.11',
#   'wall st q420': '0.10',
#   'wall st q320': '0.16',
#   'wall st q220': '-',
#   'wall st q120': '-',
#   'actual q321': '0.02',
#   'actual q221': '0.10',
#   'actual q420': '0.18',
#   'actual q320': '-0.10',
#   'actual q220': '0.09',
#   'actual q120': '0.02'},
#  13: {'tickers': 'LRN',
#   'Name': 'Stride, Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '34',
#   'Analysts': '84',
#   'estimize q321': '0.49',
#   'estimize q221': '0.58',
#   'estimize q420': '-0.25',
#   'estimize q320': '0.05',
#   'estimize q220': '0.23',
#   'estimize q120': '0.52',
#   'estimize mean q321': '0.49',
#   'estimize mean q221': '0.59',
#   'estimize mean q420': '-0.24',
#   'estimize mean q320': '0.05',
#   'estimize mean q220': '0.26',
#   'estimize mean q120': '0.52',
#   'wall st q321': '0.45',
#   'wall st q221': '0.49',
#   'wall st q420': '-0.32',
#   'wall st q320': '0.03',
#   'wall st q220': '0.20',
#   'wall st q120': '0.49',
#   'actual q321': '0.57',
#   'actual q221': '0.60',
#   'actual q420': '0.30',
#   'actual q320': '0.12',
#   'actual q220': '0.22',
#   'actual q120': '0.52'},
#  14: {'tickers': 'CSV',
#   'Name': 'Carriage Services Inc',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '23',
#   'Analysts': '36',
#   'estimize q321': '0.62',
#   'estimize q221': '0.57',
#   'estimize q420': '0.61',
#   'estimize q320': '-',
#   'estimize q220': '-',
#   'estimize q120': '0.33',
#   'estimize mean q321': '0.62',
#   'estimize mean q221': '0.56',
#   'estimize mean q420': '0.61',
#   'estimize mean q320': '-',
#   'estimize mean q220': '-',
#   'estimize mean q120': '0.30',
#   'wall st q321': '0.60',
#   'wall st q221': '0.49',
#   'wall st q420': '0.58',
#   'wall st q320': '0.49',
#   'wall st q220': '0.35',
#   'wall st q120': '0.35',
#   'actual q321': '0.82',
#   'actual q221': '0.64',
#   'actual q420': '0.81',
#   'actual q320': '0.57',
#   'actual q220': '0.51',
#   'actual q120': '0.45'},
#  15: {'tickers': 'ZVO',
#   'Name': 'Zovio, Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '14',
#   'Analysts': '61',
#   'estimize q321': '-',
#   'estimize q221': '-',
#   'estimize q420': '0.04',
#   'estimize q320': '-0.03',
#   'estimize q220': '-',
#   'estimize q120': '0.08',
#   'estimize mean q321': '-',
#   'estimize mean q221': '-',
#   'estimize mean q420': '0.04',
#   'estimize mean q320': '-0.05',
#   'estimize mean q220': '-',
#   'estimize mean q120': '0.05',
#   'wall st q321': '-0.08',
#   'wall st q221': '-0.06',
#   'wall st q420': '0.01',
#   'wall st q320': '-0.06',
#   'wall st q220': '0.02',
#   'wall st q120': '0.11',
#   'actual q321': '-0.12',
#   'actual q221': '-0.02',
#   'actual q420': '-0.10',
#   'actual q320': '0.03',
#   'actual q220': '0.09',
#   'actual q120': '0.24'},
#  16: {'tickers': 'SCI',
#   'Name': 'Service Corp. International',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '29',
#   'Analysts': '22',
#   'estimize q321': '0.68',
#   'estimize q221': '0.75',
#   'estimize q420': '0.95',
#   'estimize q320': '0.93',
#   'estimize q220': '0.45',
#   'estimize q120': '0.22',
#   'estimize mean q321': '0.62',
#   'estimize mean q221': '0.73',
#   'estimize mean q420': '0.97',
#   'estimize mean q320': '0.94',
#   'estimize mean q220': '0.44',
#   'estimize mean q120': '0.22',
#   'wall st q321': '0.60',
#   'wall st q221': '0.67',
#   'wall st q420': '0.99',
#   'wall st q320': '0.91',
#   'wall st q220': '0.42',
#   'wall st q120': '0.24',
#   'actual q321': '1.16',
#   'actual q221': '0.92',
#   'actual q420': '1.32',
#   'actual q320': '0.79',
#   'actual q220': '0.79',
#   'actual q120': '0.58'},
#  17: {'tickers': 'WW',
#   'Name': 'WW International, Inc.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '214',
#   'Analysts': '429',
#   'estimize q321': '0.70',
#   'estimize q221': '0.70',
#   'estimize q420': '-0.18',
#   'estimize q320': '0.37',
#   'estimize q220': '0.65',
#   'estimize q120': '0.67',
#   'estimize mean q321': '0.71',
#   'estimize mean q221': '0.71',
#   'estimize mean q420': '-0.17',
#   'estimize mean q320': '0.36',
#   'estimize mean q220': '0.64',
#   'estimize mean q120': '0.70',
#   'wall st q321': '0.73',
#   'wall st q221': '0.66',
#   'wall st q420': '-0.25',
#   'wall st q320': '0.32',
#   'wall st q220': '0.62',
#   'wall st q120': '0.70',
#   'actual q321': '0.77',
#   'actual q221': '0.48',
#   'actual q420': '-0.20',
#   'actual q320': '0.39',
#   'actual q220': '0.69',
#   'actual q120': '0.67'},
#  18: {'tickers': 'BID',
#   'Name': "Sotheby's",
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '69',
#   'Analysts': '92',
#   'estimize q321': '-',
#   'estimize q221': '0.10',
#   'estimize q420': '1.52',
#   'estimize q320': '-0.52',
#   'estimize q220': '1.62',
#   'estimize q120': '-0.19',
#   'estimize mean q321': '-',
#   'estimize mean q221': '0.10',
#   'estimize mean q420': '1.49',
#   'estimize mean q320': '-0.50',
#   'estimize mean q220': '1.56',
#   'estimize mean q120': '-0.20',
#   'wall st q321': '-',
#   'wall st q221': '-',
#   'wall st q420': '-',
#   'wall st q320': '-',
#   'wall st q220': '-',
#   'wall st q120': '-',
#   'actual q321': '1.47',
#   'actual q221': '-0.15',
#   'actual q420': '1.74',
#   'actual q320': '-0.41',
#   'actual q220': '1.09',
#   'actual q120': '0.09'},
#  19: {'tickers': 'RGS',
#   'Name': 'Regis Corp.',
#   'Sector': 'Consumer Discretionary',
#   'Industry': 'Diversified Consumer Services',
#   'followers': '26',
#   'Analysts': '53',
#   'estimize q321': '-',
#   'estimize q221': '-',
#   'estimize q420': '-',
#   'estimize q320': '-0.55',
#   'estimize q220': '-0.17',
#   'estimize q120': '-0.01',
#   'estimize mean q321': '-',
#   'estimize mean q221': '-',
#   'estimize mean q420': '-',
#   'estimize mean q320': '-0.13',
#   'estimize mean q220': '-0.12',
#   'estimize mean q120': '0.04',
#   'wall st q321': '-0.02',
#   'wall st q221': '-0.16',
#   'wall st q420': '-0.13',
#   'wall st q320': '-0.66',
#   'wall st q220': '-0.43',
#   'wall st q120': '-0.08',
#   'actual q321': '-0.70',
#   'actual q221': '-0.72',
#   'actual q420': '-0.78',
#   'actual q320': '-1.01',
#   'actual q220': '-0.12',
#   'actual q120': '0.13'}}

# %%
with open('companies.json', 'w') as outfile:
    json.dump(dbq2, outfile, indent=4)
